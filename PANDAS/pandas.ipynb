# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50,60])
s.name = "Calories"
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: Calories, dtype: int64

# %%
s.dtype
s.values
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s[0:3]
# Out:
# 0    10
# 1    20
# 2    30
# Name: Calories, dtype: int64

# %%
#iloc -> location based indexing
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[0:3]
# Out:
# 0    10
# 1    20
# 2    30
# Name: Calories, dtype: int64

# %%
index = ["apple", "banana", "orange", "grapes", "mango", "kiwi"]
s.index = index
print(s)
print(s["grapes"])
# Out:
# apple     10
# banana    20
# orange    30
# grapes    40
# mango     50
# kiwi      60
# Name: Calories, dtype: int64
# 40

# %%
#loc -> label based indexing
print(s.loc[["grapes", "mango"]])
#In the label based indexing your start as well as end index is included in the output.
s.loc["banana":"grapes"]
# Out:
# grapes    40
# mango     50
# Name: Calories, dtype: int64
# banana    20
# orange    30
# grapes    40
# Name: Calories, dtype: int64

# %%
fruit_protin = {
    "apple": 5.3,
    "banana": 1.3,
    "orange": 0.9,
    "grapes": 2.6,
    "mango": 0.8,
    "kiwi": 1.1,
    "avacado": 2.0
}
s2 = pd.Series(fruit_protin,name="Protein")
print(s2)
# Out:
# apple      5.3
# banana     1.3
# orange     0.9
# grapes     2.6
# mango      0.8
# kiwi       1.1
# avacado    2.0
# Name: Protein, dtype: float64

# %%
# conditional selection
s2[s2>1]
s2[(s2>0.5) & (s2<=2)] #&
s2[~(s2 > 1)]
# Out:
# orange    0.9
# mango     0.8
# Name: Protein, dtype: float64

# %%
#Modifying the values in the series
s2["mango"] = 6.09
s2
# Out:
# apple      5.30
# banana     1.30
# orange     0.90
# grapes     2.60
# mango      6.09
# kiwi       1.10
# avacado    2.00
# Name: Protein, dtype: float64

# %% [markdown]
# ## Data Frame

# %%
import numpy as np
#data frame
data = {
    "name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "age": [25, 30, np.nan, 40, 45],
    "department": ["HR", "IT", "Finance", "Marketing", "Sales"],
    "salary": [50000, 60000, 30000, 80000, 90000,]
}

# %%
data
# Out:
# {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
#  'age': [25, 30, nan, 40, 45],
#  'department': ['HR', 'IT', 'Finance', 'Marketing', 'Sales'],
#  'salary': [50000, 60000, 30000, 80000, 90000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name   age department  salary
# 0    Alice  25.0         HR   50000
# 1      Bob  30.0         IT   60000
# 2  Charlie   NaN    Finance   30000
# 3    David  40.0  Marketing   80000
# 4      Eve  45.0      Sales   90000

# %%
df.head(2)
# Out:
#     name   age department  salary
# 0  Alice  25.0         HR   50000
# 1    Bob  30.0         IT   60000

# %%
#loc and iloc also works in data frame
df.iloc[1:3]
# Out:
#       name   age department  salary
# 1      Bob  30.0         IT   60000
# 2  Charlie   NaN    Finance   30000

# %%
df.loc[1:3, ["name", "department"]]
# Out:
#       name department
# 1      Bob         IT
# 2  Charlie    Finance
# 3    David  Marketing

# %%
#individual column selection
df["name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# Name: name, dtype: str

# %%
#drop a column
df.drop("age", axis=1 ,inplace=True) #use inplace if you want to make changes in original data frame
df
# Out:
#       name department  salary
# 0    Alice         HR   50000
# 1      Bob         IT   60000
# 2  Charlie    Finance   30000
# 3    David  Marketing   80000
# 4      Eve      Sales   90000

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        5 non-null      str
#  1   department  5 non-null      str
#  2   salary      5 non-null      int64
# dtypes: int64(1), str(2)
# memory usage: 252.0 bytes

# %%
df.describe()
# Out:
#              salary
# count      5.000000
# mean   62000.000000
# std    23874.672773
# min    30000.000000
# 25%    50000.000000
# 50%    60000.000000
# 75%    80000.000000
# max    90000.000000

# %%
# Broad casting
df["salary"] = df["salary"] + 5000
df
# Out:
#       name department  salary
# 0    Alice         HR   55000
# 1      Bob         IT   65000
# 2  Charlie    Finance   35000
# 3    David  Marketing   85000
# 4      Eve      Sales   95000

# %%
#renaming the column name
df.rename(columns = {'department': 'dept'} , inplace = True)
df
# Out:
#       name       dept  salary
# 0    Alice         HR   55000
# 1      Bob         IT   65000
# 2  Charlie    Finance   35000
# 3    David  Marketing   85000
# 4      Eve      Sales   95000

# %%
df['dept'].unique()
# Out:
# <StringArray>
# ['HR', 'IT', 'Finance', 'Marketing', 'Sales']
# Length: 5, dtype: str

# %%
df["dept"].value_counts()
# Out:
# dept
# HR           1
# IT           1
# Finance      1
# Marketing    1
# Sales        1
# Name: count, dtype: int64

# %%
df["promoted_salary"] = df['salary'] * 10
df
# Out:
#       name       dept  salary  promoted_salary
# 0    Alice         HR   55000           550000
# 1      Bob         IT   65000           650000
# 2  Charlie    Finance   35000           350000
# 3    David  Marketing   85000           850000
# 4      Eve      Sales   95000           950000

# %%
#data cleaning
df.isnull().sum()
# Out:
# name               0
# dept               0
# salary             0
# promoted_salary    0
# dtype: int64

# %%
# df.dropna()#used to drop any null values from the data frame
# df.dropna(how="all")#used to drop rows where all values are null
# df.dropna(how="any")#used to drop rows where any value is null
df
# Out:
#       name       dept  salary  promoted_salary
# 0    Alice         HR   55000           550000
# 1      Bob         IT   65000           650000
# 2  Charlie    Finance   35000           350000
# 3    David  Marketing   85000           850000
# 4      Eve      Sales   95000           950000

# %%
df.fillna(df["age"].mean())
# Out:
#       name   age department  salary
# 0    Alice  25.0         HR   50000
# 1      Bob  30.0         IT   60000
# 2  Charlie  35.0    Finance   30000
# 3    David  40.0  Marketing   80000
# 4      Eve  45.0      Sales   90000

# %%
df["name"]=df["name"].replace("Alice", "Mukesh")
df
# Out:
#       name   age department  salary
# 0   Mukesh  25.0         HR   50000
# 1      Bob  30.0         IT   60000
# 2  Charlie   NaN    Finance   30000
# 3    David  40.0  Marketing   80000
# 4      Eve  45.0      Sales   90000

# %%
df['salary'] = df['salary'].apply(lambda x: x * 2 if x < 100000 else  x)
df
# Out:
#       name   age department    salary
# 0    Alice  25.0         HR  160000.0
# 1      Bob  30.0         IT  192000.0
# 2  Charlie   NaN    Finance  192000.0
# 3    David  40.0  Marketing  256000.0
# 4      Eve  45.0      Sales  288000.0

# %%
# name = "alice_fernandez"
# df[["first_name","last_name"]] = df['name'].str.split("_")

# %%
# apply and lambda
def multiply_age(x):
    return x * 2
df["age"] = df["age"].apply(multiply_age)
df
# Out:
#       name   age department  salary
# 0    Alice  50.0         HR   50000
# 1      Bob  60.0         IT   60000
# 2  Charlie   NaN    Finance   30000
# 3    David  80.0  Marketing   80000
# 4      Eve  90.0      Sales   90000

# %%
df["age"] = df["age"].apply(lambda x: x / 2)
df
# Out:
#       name   age department  salary
# 0    Alice  25.0         HR   50000
# 1      Bob  30.0         IT   60000
# 2  Charlie   NaN    Finance   30000
# 3    David  40.0  Marketing   80000
# 4      Eve  45.0      Sales   90000

# %%
#join and merges
department_info ={
    "department":["HR","IT","FINANCE"],
    "location":["NEW YORK", "SAN FRANCISCO", "CHICAGO"],
    "manager":["Laura", "John", "Emily"]
}
df2 = pd.DataFrame(department_info)
df2
# Out:
#   department       location manager
# 0         HR       NEW YORK   Laura
# 1         IT  SAN FRANCISCO    John
# 2    FINANCE        CHICAGO   Emily

# %%
#Concat
df_concat = pd.concat([df, df2])
df_concat
# Out:
#       name   age department   salary       location manager
# 0    Alice  25.0         HR  50000.0            NaN     NaN
# 1      Bob  30.0         IT  60000.0            NaN     NaN
# 2  Charlie   NaN    Finance  30000.0            NaN     NaN
# 3    David  40.0  Marketing  80000.0            NaN     NaN
# 4      Eve  45.0      Sales  90000.0            NaN     NaN
# 0      NaN   NaN         HR      NaN       NEW YORK   Laura
# 1      NaN   NaN         IT      NaN  SAN FRANCISCO    John
# 2      NaN   NaN    FINANCE      NaN        CHICAGO   Emily

# %%
pd.concat([df, df2], axis=1)
# Out:
#       name   age department  salary department       location manager
# 0    Alice  25.0         HR   50000         HR       NEW YORK   Laura
# 1      Bob  30.0         IT   60000         IT  SAN FRANCISCO    John
# 2  Charlie   NaN    Finance   30000    FINANCE        CHICAGO   Emily
# 3    David  40.0  Marketing   80000        NaN            NaN     NaN
# 4      Eve  45.0      Sales   90000        NaN            NaN     NaN

# %%
pd.merge(df,df2,on="department")
# Out:
#     name   age department  salary       location manager
# 0  Alice  25.0         HR   50000       NEW YORK   Laura
# 1    Bob  30.0         IT   60000  SAN FRANCISCO    John

# %%
#operations on file
data = pd.read_csv("sales.csv")
data.head()
# Out:
#    P_ID        P_Name     Category  Qty_Sold  Unit_Price  Total_Sales  \
# 0  P101        Laptop  Electronics         5       55000       275000
# 1  P102    Smartphone  Electronics         8       20000       160000
# 2  P103  Office Chair    Furniture        10        4500        45000
# 3  P104       Printer  Electronics         3       12000        36000
# 4  P105   Study Table    Furniture         4        7000        28000
#
#    Order_Date Region       Ship_Mode Customer_Segment  Profit
# 0  10/01/2026   West  Standard Class         Consumer   35000
# 1  12/01/2026   East    Second Class        Corporate   22000
# 2  14/01/2026  South  Standard Class      Home Office    7000
# 3  16/01/2026  North     First Class         Consumer    5000
# 4  18/01/2026   West        Same Day        Corporate    4000

# %%
data.shape
# Out:
# (10, 11)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   P_ID              10 non-null     str
#  1   P_Name            10 non-null     str
#  2   Category          10 non-null     str
#  3   Qty_Sold          10 non-null     int64
#  4   Unit_Price        10 non-null     int64
#  5   Total_Sales       10 non-null     int64
#  6   Order_Date        10 non-null     str
#  7   Region            10 non-null     str
#  8   Ship_Mode         10 non-null     str
#  9   Customer_Segment  10 non-null     str
#  10  Profit            10 non-null     int64
# dtypes: int64(4), str(7)
# memory usage: 1012.0 bytes
